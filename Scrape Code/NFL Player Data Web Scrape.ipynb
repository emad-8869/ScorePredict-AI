# %%
# All necessary imports
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import time
import os
import io

# %%
def scrape_player_gamelog(player_id, name):
    """
    Scrapes game logs for a player from Pro Football Reference
    """
    # Construct URL using player ID
    url = f'https://www.pro-football-reference.com/players/{player_id[0]}/{player_id}/gamelog/'
    print(f"Attempting to scrape: {url}")
    
    try:
        # Open URL and create BeautifulSoup object
        html = urlopen(url)
        soup = BeautifulSoup(html, 'html.parser')
        
        # Find the regular season table (it has id='stats')
        table_html = soup.find('table', {'id': 'stats'})
        
        if table_html is None:
            print(f"Could not find stats table for {name}")
            return None
        
        # Convert to DataFrame using StringIO to handle deprecation warning
        df = pd.read_html(io.StringIO(str(table_html)))[0]
        
        # Clean up the DataFrame
        # Remove multi-level column headers if they exist
        if isinstance(df.columns, pd.MultiIndex):
            df.columns = df.columns.get_level_values(-1)
        
        # Drop rows that contain header information
        df = df[df['Rk'] != 'Rk']
        
        # Drop rows where Rk is NaN (usually indicates section breaks)
        df = df.dropna(subset=['Rk'])
        
        print(f"Successfully found game log with {len(df)} rows")
        return df
        
    except Exception as e:
        print(f"Error scraping data for {name}: {str(e)}")
        return None

def process_roster(roster_file, output_folder):
    """
    Process entire roster and save individual player stats
    """
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        print(f"Created output folder: {output_folder}")
    
    # Read roster file
    print(f"Reading roster file: {roster_file}")
    roster = pd.read_csv(roster_file)
    print(f"Found {len(roster)} players in roster")
    
    # Initialize counters
    successful = 0
    failed = 0
    
    # Process each player
    for index, row in roster.iterrows():
        player_id = row['Player-additional']
        name = row['Player']
        
        print(f"\nProcessing player {index + 1} of {len(roster)}: {name}")
        
        # Skip if no player ID
        if pd.isna(player_id):
            print(f"No ID found for {name}, skipping...")
            failed += 1
            continue
        
        # Scrape player's game log
        game_log = scrape_player_gamelog(player_id, name)
        
        if game_log is not None:
            # Clean up filename - remove any characters that might cause issues
            safe_name = "".join(x for x in name if x.isalnum() or x in [' ', '-', '_'])
            filename = os.path.join(output_folder, f"{safe_name}_gamelog.csv")
            
            # Save to CSV
            game_log.to_csv(filename, index=False)
            print(f"Saved game log to: {filename}")
            successful += 1
        else:
            failed += 1
        
        # Add delay to avoid overwhelming the server
        print("Waiting 3 seconds before next player...")
        time.sleep(3)
    
    # Print summary
    print(f"\nProcessing complete!")
    print(f"Successfully processed: {successful} players")
    print(f"Failed to process: {failed} players")

# Example usage
team_name = "Commanders" # Enter Nickname of team (Bears, Eagles, Commanders, etc.)

roster_file = f'Rosters/{team_name}_roster.csv'  # Your roster CSV file
output_folder = f'Player_Logs/{team_name}'  # Folder where individual player data will be saved

process_roster(roster_file, output_folder)
# Out:
# Created output folder: Player_Logs/Commanders
# Reading roster file: Rosters/Commanders_roster.csv
# Found 60 players in roster
#
# Processing player 1 of 60: Nick Allegretti
# Attempting to scrape: https://www.pro-football-reference.com/players/A/AlleNi00/gamelog/
# Successfully found game log with 94 rows
# Saved game log to: Player_Logs/Commanders\Nick Allegretti_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 2 of 60: Dorance Armstrong Jr.
# Attempting to scrape: https://www.pro-football-reference.com/players/A/ArmsDo00/gamelog/
# Successfully found game log with 110 rows
# Saved game log to: Player_Logs/Commanders\Dorance Armstrong Jr_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 3 of 60: John Bates
# Attempting to scrape: https://www.pro-football-reference.com/players/B/BateJo00/gamelog/
# Successfully found game log with 62 rows
# Saved game log to: Player_Logs/Commanders\John Bates_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 4 of 60: Nick Bellore
# Attempting to scrape: https://www.pro-football-reference.com/players/B/BellNi01/gamelog/
# Successfully found game log with 221 rows
# Saved game log to: Player_Logs/Commanders\Nick Bellore_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 5 of 60: Tyler Biadasz
# Attempting to scrape: https://www.pro-football-reference.com/players/B/BiadTy00/gamelog/
# Successfully found game log with 78 rows
# Saved game log to: Player_Logs/Commanders\Tyler Biadasz_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 6 of 60: Dyami Brown
# Attempting to scrape: https://www.pro-football-reference.com/players/B/BrowDy00/gamelog/
# Successfully found game log with 62 rows
# Saved game log to: Player_Logs/Commanders\Dyami Brown_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 7 of 60: Noah Brown
# Attempting to scrape: https://www.pro-football-reference.com/players/B/BrowNo00/gamelog/
# Successfully found game log with 111 rows
# Saved game log to: Player_Logs/Commanders\Noah Brown_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 8 of 60: Percy Butler
# Attempting to scrape: https://www.pro-football-reference.com/players/B/ButlPe00/gamelog/
# Successfully found game log with 45 rows
# Saved game log to: Player_Logs/Commanders\Percy Butler_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 9 of 60: Jeremy Chinn
# Attempting to scrape: https://www.pro-football-reference.com/players/C/ChinJe00/gamelog/
# Successfully found game log with 78 rows
# Saved game log to: Player_Logs/Commanders\Jeremy Chinn_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 10 of 60: Brandon Coleman
# Attempting to scrape: https://www.pro-football-reference.com/players/C/ColeBr02/gamelog/
# Successfully found game log with 11 rows
# Saved game log to: Player_Logs/Commanders\Brandon Coleman_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 11 of 60: Samuel Cosmi
# Attempting to scrape: https://www.pro-football-reference.com/players/C/CosmSa00/gamelog/
# Successfully found game log with 62 rows
# Saved game log to: Player_Logs/Commanders\Samuel Cosmi_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 12 of 60: Jayden Daniels
# Attempting to scrape: https://www.pro-football-reference.com/players/D/DaniJa02/gamelog/
# Successfully found game log with 11 rows
# Saved game log to: Player_Logs/Commanders\Jayden Daniels_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 13 of 60: Michael Davis
# Attempting to scrape: https://www.pro-football-reference.com/players/D/DaviMi03/gamelog/
# Successfully found game log with 125 rows
# Saved game log to: Player_Logs/Commanders\Michael Davis_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 14 of 60: Sheldon Day
# Attempting to scrape: https://www.pro-football-reference.com/players/D/DayxSh00/gamelog/
# Successfully found game log with 120 rows
# Saved game log to: Player_Logs/Commanders\Sheldon Day_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 15 of 60: Michael Deiter
# Attempting to scrape: https://www.pro-football-reference.com/players/D/DeitMi00/gamelog/
# Successfully found game log with 94 rows
# Saved game log to: Player_Logs/Commanders\Michael Deiter_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 16 of 60: Jeff Driskel
# Attempting to scrape: https://www.pro-football-reference.com/players/D/DrisJe00/gamelog/
# Successfully found game log with 121 rows
# Saved game log to: Player_Logs/Commanders\Jeff Driskel_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 17 of 60: Austin Ekeler
# Attempting to scrape: https://www.pro-football-reference.com/players/E/EkelAu00/gamelog/
# Successfully found game log with 126 rows
# Saved game log to: Player_Logs/Commanders\Austin Ekeler_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 18 of 60: Zach Ertz
# Attempting to scrape: https://www.pro-football-reference.com/players/E/ErtzZa00/gamelog/
# Successfully found game log with 186 rows
# Saved game log to: Player_Logs/Commanders\Zach Ertz_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 19 of 60: Clelin Ferrell
# Attempting to scrape: https://www.pro-football-reference.com/players/F/FerrCl00/gamelog/
# Successfully found game log with 94 rows
# Saved game log to: Player_Logs/Commanders\Clelin Ferrell_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 20 of 60: Emmanuel Forbes
# Attempting to scrape: https://www.pro-football-reference.com/players/F/ForbEm00/gamelog/
# Successfully found game log with 28 rows
# Saved game log to: Player_Logs/Commanders\Emmanuel Forbes_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 21 of 60: Darrick Forrest
# Attempting to scrape: https://www.pro-football-reference.com/players/F/ForrDa00/gamelog/
# Successfully found game log with 62 rows
# Saved game log to: Player_Logs/Commanders\Darrick Forrest_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 22 of 60: Dante Fowler
# Attempting to scrape: https://www.pro-football-reference.com/players/F/FowlDa00/gamelog/
# Successfully found game log with 142 rows
# Saved game log to: Player_Logs/Commanders\Dante Fowler_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 23 of 60: Dominique Hampton
# Attempting to scrape: https://www.pro-football-reference.com/players/H/HampDo00/gamelog/
# Successfully found game log with 11 rows
# Saved game log to: Player_Logs/Commanders\Dominique Hampton_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 24 of 60: Jalyn Holmes
# Attempting to scrape: https://www.pro-football-reference.com/players/H/HolmJa01/gamelog/
# Successfully found game log with 103 rows
# Saved game log to: Player_Logs/Commanders\Jalyn Holmes_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 25 of 60: Noah Igbinoghene
# Attempting to scrape: https://www.pro-football-reference.com/players/I/IgbiNo00/gamelog/
# Successfully found game log with 78 rows
# Saved game log to: Player_Logs/Commanders\Noah Igbinoghene_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 26 of 60: Marshon Lattimore
# Attempting to scrape: https://www.pro-football-reference.com/players/L/LattMa01/gamelog/
# Successfully found game log with 126 rows
# Saved game log to: Player_Logs/Commanders\Marshon Lattimore_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 27 of 60: Cornelius Lucas
# Attempting to scrape: https://www.pro-football-reference.com/players/L/LucaCo01/gamelog/
# Successfully found game log with 158 rows
# Saved game log to: Player_Logs/Commanders\Cornelius Lucas_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 28 of 60: Frankie Luvu
# Attempting to scrape: https://www.pro-football-reference.com/players/L/LuvuFr00/gamelog/
# Successfully found game log with 108 rows
# Saved game log to: Player_Logs/Commanders\Frankie Luvu_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 29 of 60: Jordan Magee
# Attempting to scrape: https://www.pro-football-reference.com/players/M/MageJo00/gamelog/
# Successfully found game log with 11 rows
# Saved game log to: Player_Logs/Commanders\Jordan Magee_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 30 of 60: Marcus Mariota
# Attempting to scrape: https://www.pro-football-reference.com/players/M/MariMa01/gamelog/
# Successfully found game log with 158 rows
# Saved game log to: Player_Logs/Commanders\Marcus Mariota_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 31 of 60: Quan Martin
# Attempting to scrape: https://www.pro-football-reference.com/players/M/MartJa04/gamelog/
# Successfully found game log with 28 rows
# Saved game log to: Player_Logs/Commanders\Quan Martin_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 32 of 60: Phidarian Mathis
# Attempting to scrape: https://www.pro-football-reference.com/players/M/MathPh00/gamelog/
# Successfully found game log with 45 rows
# Saved game log to: Player_Logs/Commanders\Phidarian Mathis_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 33 of 60: Luke McCaffrey
# Attempting to scrape: https://www.pro-football-reference.com/players/M/McCaLu00/gamelog/
# Successfully found game log with 11 rows
# Saved game log to: Player_Logs/Commanders\Luke McCaffrey_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 34 of 60: Terry McLaurin
# Attempting to scrape: https://www.pro-football-reference.com/players/M/McLaTe00/gamelog/
# Successfully found game log with 94 rows
# Saved game log to: Player_Logs/Commanders\Terry McLaurin_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 35 of 60: Jeremy McNichols
# Attempting to scrape: https://www.pro-football-reference.com/players/M/McNiJe00/gamelog/
# Successfully found game log with 84 rows
# Saved game log to: Player_Logs/Commanders\Jeremy McNichols_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 36 of 60: Jer'Zhan Newton
# Attempting to scrape: https://www.pro-football-reference.com/players/N/NewtJe00/gamelog/
# Successfully found game log with 11 rows
# Saved game log to: Player_Logs/Commanders\JerZhan Newton_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 37 of 60: Tyler Ott
# Attempting to scrape: https://www.pro-football-reference.com/players/O/OttxTy00/gamelog/
# Successfully found game log with 131 rows
# Saved game log to: Player_Logs/Commanders\Tyler Ott_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 38 of 60: Tyler Owens
# Attempting to scrape: https://www.pro-football-reference.com/players/O/OwenTy00/gamelog/
# Successfully found game log with 11 rows
# Saved game log to: Player_Logs/Commanders\Tyler Owens_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 39 of 60: Chris Paul
# Attempting to scrape: https://www.pro-football-reference.com/players/P/PaulCh00/gamelog/
# Successfully found game log with 45 rows
# Saved game log to: Player_Logs/Commanders\Chris Paul_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 40 of 60: Daron Payne
# Attempting to scrape: https://www.pro-football-reference.com/players/P/PaynDa00/gamelog/
# Successfully found game log with 110 rows
# Saved game log to: Player_Logs/Commanders\Daron Payne_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 41 of 60: Jeremy Reaves
# Attempting to scrape: https://www.pro-football-reference.com/players/R/ReavJe00/gamelog/
# Successfully found game log with 84 rows
# Saved game log to: Player_Logs/Commanders\Jeremy Reaves_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 42 of 60: Brian Robinson Jr.
# Attempting to scrape: https://www.pro-football-reference.com/players/R/RobiBr01/gamelog/
# Successfully found game log with 45 rows
# Saved game log to: Player_Logs/Commanders\Brian Robinson Jr_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 43 of 60: Chris Rodriguez
# Attempting to scrape: https://www.pro-football-reference.com/players/R/RodrCh00/gamelog/
# Successfully found game log with 28 rows
# Saved game log to: Player_Logs/Commanders\Chris Rodriguez_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 44 of 60: Mike Sainristil
# Attempting to scrape: https://www.pro-football-reference.com/players/S/SainMi00/gamelog/
# Successfully found game log with 11 rows
# Saved game log to: Player_Logs/Commanders\Mike Sainristil_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 45 of 60: Trenton Scott
# Attempting to scrape: https://www.pro-football-reference.com/players/S/ScotTr01/gamelog/
# Successfully found game log with 109 rows
# Saved game log to: Player_Logs/Commanders\Trenton Scott_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 46 of 60: Austin Seibert
# Attempting to scrape: https://www.pro-football-reference.com/players/S/SeibAu00/gamelog/
# Successfully found game log with 68 rows
# Saved game log to: Player_Logs/Commanders\Austin Seibert_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 47 of 60: Ben Sinnott
# Attempting to scrape: https://www.pro-football-reference.com/players/S/SinnBe00/gamelog/
# Successfully found game log with 11 rows
# Saved game log to: Player_Logs/Commanders\Ben Sinnott_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 48 of 60: Benjamin St-Juste
# Attempting to scrape: https://www.pro-football-reference.com/players/S/StJuBe00/gamelog/
# Successfully found game log with 62 rows
# Saved game log to: Player_Logs/Commanders\Benjamin St-Juste_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 49 of 60: Bobby Wagner
# Attempting to scrape: https://www.pro-football-reference.com/players/W/WagnBo00/gamelog/
# Successfully found game log with 206 rows
# Saved game log to: Player_Logs/Commanders\Bobby Wagner_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 50 of 60: Mykal Walker
# Attempting to scrape: https://www.pro-football-reference.com/players/W/WalkMy00/gamelog/
# Successfully found game log with 76 rows
# Saved game log to: Player_Logs/Commanders\Mykal Walker_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 51 of 60: Tress Way
# Attempting to scrape: https://www.pro-football-reference.com/players/W/WayxTr00/gamelog/
# Successfully found game log with 174 rows
# Saved game log to: Player_Logs/Commanders\Tress Way_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 52 of 60: Andrew Wylie
# Attempting to scrape: https://www.pro-football-reference.com/players/W/WyliAn00/gamelog/
# Successfully found game log with 110 rows
# Saved game log to: Player_Logs/Commanders\Andrew Wylie_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 53 of 60: Olamide Zaccheaus
# Attempting to scrape: https://www.pro-football-reference.com/players/Z/ZaccOl01/gamelog/
# Successfully found game log with 94 rows
# Saved game log to: Player_Logs/Commanders\Olamide Zaccheaus_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 54 of 60: Kevon Seymour (SUS)
# Attempting to scrape: https://www.pro-football-reference.com/players/S/SeymKe00/gamelog/
# Successfully found game log with 95 rows
# Saved game log to: Player_Logs/Commanders\Kevon Seymour SUS_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 55 of 60: Jonathan Allen (IR)
# Attempting to scrape: https://www.pro-football-reference.com/players/A/AlleJo01/gamelog/
# Successfully found game log with 126 rows
# Saved game log to: Player_Logs/Commanders\Jonathan Allen IR_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 56 of 60: Jamison Crowder (IR)
# Attempting to scrape: https://www.pro-football-reference.com/players/C/CrowJa00/gamelog/
# Successfully found game log with 157 rows
# Saved game log to: Player_Logs/Commanders\Jamison Crowder IR_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 57 of 60: Javontae Jean-Baptiste (IR)
# Attempting to scrape: https://www.pro-football-reference.com/players/J/JeanJa00/gamelog/
# Successfully found game log with 11 rows
# Saved game log to: Player_Logs/Commanders\Javontae Jean-Baptiste IR_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 58 of 60: Norell Pollard (IR)
# Attempting to scrape: https://www.pro-football-reference.com/players/P/PollNo00/gamelog/
# Successfully found game log with 11 rows
# Saved game log to: Player_Logs/Commanders\Norell Pollard IR_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 59 of 60: Colson Yankoff (IR)
# Attempting to scrape: https://www.pro-football-reference.com/players/Y/YankCo00/gamelog/
# Successfully found game log with 11 rows
# Saved game log to: Player_Logs/Commanders\Colson Yankoff IR_gamelog.csv
# Waiting 3 seconds before next player...
#
# Processing player 60 of 60: Team Total
# Attempting to scrape: https://www.pro-football-reference.com/players/-/-9999/gamelog/
# Error scraping data for Team Total: HTTP Error 500: Internal Server Error
# Waiting 3 seconds before next player...
#
# Processing complete!
# Successfully processed: 59 players
# Failed to process: 1 players
