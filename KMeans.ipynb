# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Set OMP_NUM_THREADS to avoid memory leak warning
os.environ['OMP_NUM_THREADS'] = '1'

# Load prediction datasets from FF_Predictions folder
predictions_path = 'FF_Predictions'
prediction_files = {
    'K': os.path.join(predictions_path, 'K_predictions.csv'),
    'QB': os.path.join(predictions_path, 'QB_predictions.csv'),
    'RB': os.path.join(predictions_path, 'RB_predictions.csv'),
    'TE': os.path.join(predictions_path, 'TE_predictions.csv'),
    'WR': os.path.join(predictions_path, 'WR_predictions.csv')
}

# Load and combine prediction data
dfs = []
for position, file_path in prediction_files.items():
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        df['Position'] = position
        dfs.append(df)

combined_predictions = pd.concat(dfs, ignore_index=True)

# Select relevant features for clustering
features = [
    'Games_Played',
    'sample_weight',
    'predicted_points'
]

# Additional position-specific features
position_features = {
    'QB': ['Yds_avg', 'TD_avg', 'Int_avg', 'Rate_avg', 'FL_avg'],
    'RB': ['Yds_avg', 'TD_avg', 'Rec_avg', 'FL_avg'],
    'WR': ['Rec_avg', 'Yds_avg', 'TD_avg', 'FL_avg'],
    'TE': ['Rec_avg', 'Yds_avg', 'TD_avg', 'FL_avg'],
    'K': ['FG%_avg', 'XP%_avg', 'Pts_avg']
}

# Create separate clustering analyses for each position
for position in prediction_files.keys():
    print(f"\nProcessing {position}...")
    
    position_df = combined_predictions[combined_predictions['Position'] == position].copy()
    position_df = position_df.reset_index(drop=True)
    
    # Get relevant features for this position
    current_features = features + position_features.get(position, [])
    available_features = [f for f in current_features if f in position_df.columns]
    
    if len(position_df) < 2:
        print(f"Insufficient data for position {position}")
        continue
        
    # Scale the features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(position_df[available_features])
    
    # Apply KMeans clustering
    n_clusters = min(len(position_df), 3)
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    position_df['cluster'] = kmeans.fit_predict(X_scaled)
    
    # Print cluster analysis
    print(f"\nCluster Analysis for {position}:")
    for cluster in sorted(position_df['cluster'].unique()):
        cluster_data = position_df[position_df['cluster'] == cluster]
        print(f"\nCluster {cluster}:")
        print(f"Average predicted points: {cluster_data['predicted_points'].mean():.2f}")
        print(f"Range: {cluster_data['predicted_points'].min():.2f} - {cluster_data['predicted_points'].max():.2f}")
        print(f"Number of players: {len(cluster_data)}")
        print("Players:", ', '.join(sorted(cluster_data['Player'].tolist())))
        
        # Print average stats for the cluster
        print("\nCluster Averages:")
        for feature in available_features:
            print(f"{feature}: {cluster_data[feature].mean():.2f}")

print("\nClustering analysis complete.")
# Out:
# Processing K...
#
# Cluster Analysis for K:
#
# Cluster 0:
# Average predicted points: 6.35
# Range: 5.59 - 7.24
# Number of players: 8
# Players: Brandon McManus, Cairo Santos, Chase McLaughlin, Eddy Piñeiro, Graham Gano, Jake Elliott, Jason Myers, Younghoe Koo
#
# Cluster Averages:
# Games_Played: 125.75
# predicted_points: 6.35
# FG%_avg: 72.43
# XP%_avg: 82.68
# Pts_avg: 6.72
#
# Cluster 1:
# Average predicted points: 1.96
# Range: 0.87 - 3.05
# Number of players: 2
# Players: Austin Seibert, John Parker Romo
#
# Cluster Averages:
# Games_Played: 21.00
# predicted_points: 1.96
# FG%_avg: 40.05
# XP%_avg: 31.26
# Pts_avg: 3.93
#
# Cluster 2:
# Average predicted points: 3.01
# Range: 2.27 - 4.17
# Number of players: 6
# Players: Blake Grupe, Brandon Aubrey, Chad Ryland, Jake Bates, Jake Moody, Joshua Karty
#
# Cluster Averages:
# Games_Played: 21.00
# predicted_points: 3.01
# FG%_avg: 70.65
# XP%_avg: 83.81
# Pts_avg: 7.16
#
# Processing QB...
#
# Cluster Analysis for QB:
#
# Cluster 0:
# Average predicted points: 5.99
# Range: 2.11 - 10.90
# Number of players: 13
# Players: Brock Purdy, Bryce Young, Caleb Williams, Daniel Jones, Geno Smith, Jalen Hurts, Jayden Daniels, Jimmy Garoppolo, Jordan Love, Kyler Murray, Marcus Mariota, Sam Darnold, Sam Howell
#
# Cluster Averages:
# Games_Played: 53.08
# predicted_points: 5.99
# Yds_avg: 145.29
# TD_avg: 0.80
# Int_avg: 0.46
# FL_avg: 0.13
#
# Cluster 1:
# Average predicted points: 0.63
# Range: -0.05 - 2.62
# Number of players: 20
# Players: Brandon Allen, Brett Rypien, Clayton Tune, Cooper Rush, Drew Lock, Hendon Hooker, Jake Haener, Jeff Driskel, Joshua Dobbs, Kenny Pickett, Kyle Trask, Malik Willis, Michael Penix, Nick Mullens, Spencer Rattler, Stetson Bennett, Tanner McKee, Tommy DeVito, Trey Lance, Tyson Bagent
#
# Cluster Averages:
# Games_Played: 13.55
# predicted_points: 0.63
# Yds_avg: 24.56
# TD_avg: 0.11
# Int_avg: 0.10
# FL_avg: 0.04
#
# Cluster 2:
# Average predicted points: 12.97
# Range: 10.63 - 14.21
# Number of players: 6
# Players: Andy Dalton, Baker Mayfield, Derek Carr, Jared Goff, Kirk Cousins, Matthew Stafford
#
# Cluster Averages:
# Games_Played: 158.17
# predicted_points: 12.97
# Yds_avg: 215.60
# TD_avg: 1.38
# Int_avg: 0.67
# FL_avg: 0.18
#
# Processing RB...
#
# Cluster Analysis for RB:
#
# Cluster 0:
# Average predicted points: 5.10
# Range: 2.49 - 7.50
# Number of players: 8
# Players: Bijan Robinson, Bucky Irving, Chuba Hubbard, Jahmyr Gibbs, Kenneth Walker III, Kyren Williams, Rachaad White, Tyrone Tracy
#
# Cluster Averages:
# Games_Played: 31.50
# predicted_points: 5.10
# Yds_avg: 52.73
# TD_avg: 0.41
# Rec_avg: 2.50
# FL_avg: 0.09
#
# Cluster 1:
# Average predicted points: 1.16
# Range: 0.00 - 4.19
# Number of players: 33
# Players: Avery Williams, Blake Corum, Cam Akers, Chris Brooks, Chris Rodriguez, Cody Schrader, Craig Reynolds, DeeJay Dallas, Deuce Vaughn, Emanuel Wilson, Emari Demercado, Eric Gray, Hunter Luepke, Isaac Guerendo, Jase McClellan, Jeremy McNichols, Jonathon Brooks, Jordan Mason, Jordan Mims, Kenneth Gainwell, Kenny McIntosh, Raheem Blackshear, Rico Dowdle, Ronnie Rivers, Roschon Johnson, Sean Tucker, Sione Vaki, Travis Homer, Trey Benson, Ty Chandler, Tyler Allgeier, Will Shipley, Zach Charbonnet
#
# Cluster Averages:
# Games_Played: 27.48
# predicted_points: 1.16
# Yds_avg: 10.42
# TD_avg: 0.06
# Rec_avg: 0.50
# FL_avg: 0.01
#
# Cluster 2:
# Average predicted points: 10.40
# Range: 6.46 - 13.07
# Number of players: 11
# Players: Aaron Jones, Alvin Kamara, Austin Ekeler, Christian McCaffrey, David Montgomery, Devin Singletary, Ezekiel Elliott, Jamaal Williams, James Conner, Josh Jacobs, Saquon Barkley
#
# Cluster Averages:
# Games_Played: 101.91
# predicted_points: 10.40
# Yds_avg: 51.34
# TD_avg: 0.41
# Rec_avg: 2.74
# FL_avg: 0.07
#
# Processing TE...
#
# Cluster Analysis for TE:
#
# Cluster 0:
# Average predicted points: 3.98
# Range: 2.37 - 5.47
# Number of players: 7
# Players: Cade Otton, Foster Moreau, Gerald Everett, Marcedes Lewis, Taysom Hill, Tommy Tremble, Tucker Kraft
#
# Cluster Averages:
# Games_Played: 101.57
# predicted_points: 3.98
# Rec_avg: 1.76
# Yds_avg: 20.32
# TD_avg: 0.19
# FL_avg: 0.03
#
# Cluster 1:
# Average predicted points: 0.74
# Range: 0.00 - 2.36
# Number of players: 33
# Players: AJ Barner, Ben Sims, Ben Sinnott, Brady Russell, Brayden Willis, Brevyn Spann-Ford, Brock Wright, Charlie Woerner, Chris Manhertz, Colby Parkinson, Dallin Holker, Daniel Bellinger, Davis Allen, Devin Culp, Elijah Higgins, Eric Saubert, Feleipe Franks, Grant Calcaterra, Hunter Long, Jake Tonges, John Bates, John FitzPatrick, Johnny Mundt, Josh Oliver, Ko Kieft, Luke Schoonmaker, Payne Durham, Pharaoh Brown, Ross Dwelley, Shane Zylstra, Theo Johnson, Tip Reiman, Travis Vokolek
#
# Cluster Averages:
# Games_Played: 38.70
# predicted_points: 0.74
# Rec_avg: 0.50
# Yds_avg: 4.88
# TD_avg: 0.04
# FL_avg: 0.00
#
# Cluster 2:
# Average predicted points: 7.56
# Range: 4.53 - 11.49
# Number of players: 10
# Players: Cole Kmet, Dallas Goedert, George Kittle, Jake Ferguson, Juwan Johnson, Kyle Pitts, Noah Fant, Sam LaPorta, Trey McBride, Zach Ertz
#
# Cluster Averages:
# Games_Played: 75.20
# predicted_points: 7.56
# Rec_avg: 3.29
# Yds_avg: 37.34
# TD_avg: 0.23
# FL_avg: 0.01
#
# Processing WR...
#
# Cluster Analysis for WR:
#
# Cluster 0:
# Average predicted points: 0.79
# Range: 0.00 - 3.00
# Number of players: 35
# Players: Ainias Smith, Bo Melton, Brandon Powell, Bryce Ford-Wheaton, Casey Washington, Cody White, Dareke Young, Deven Thompkins, Dyami Brown, Ihmir Smith-Marsette, Jacob Cowing, Jake Bobo, Jalen Brooks, Jalen Coker, Jalen McMillan, Jalen Nailor, Jalen Tolbert, Jalin Hyatt, Jameson Williams, Johnny Wilson, Jonathan Mingo, Jordan Whittington, Luke McCaffrey, Malik Heath, Mason Tipton, Rakim Jarrett, Ricky Pearsall, Ronnie Bell, Ryan Flournoy, Ryan Miller, Tutu Atwell, Tyler Johnson, Tyler Scott, Xavier Smith, Xavier Weaver
#
# Cluster Averages:
# Games_Played: 21.06
# predicted_points: 0.79
# Rec_avg: 0.69
# Yds_avg: 8.12
# TD_avg: 0.04
# FL_avg: 0.01
#
# Cluster 1:
# Average predicted points: 10.78
# Range: 3.54 - 15.97
# Number of players: 18
# Players: Adam Thielen, Allen Robinson, CeeDee Lamb, Cooper Kupp, Darnell Mooney, DeVonta Smith, Deebo Samuel, Drake London, Jaxon Smith-Njigba, Jayden Reed, Jordan Addison, Justin Jefferson, Keenan Allen, Malik Nabers, Mike Evans, Puka Nacua, Terry McLaurin, Tyler Lockett
#
# Cluster Averages:
# Games_Played: 81.00
# predicted_points: 10.78
# Rec_avg: 4.49
# Yds_avg: 58.14
# TD_avg: 0.35
# FL_avg: 0.02
#
# Cluster 2:
# Average predicted points: 3.63
# Range: 1.40 - 7.65
# Number of players: 27
# Players: Chris Conley, Christian Watson, Darius Slayton, David Moore, DeAndre Carter, Demarcus Robinson, Dontayvion Wicks, Greg Dortch, Jahan Dotson, Jauan Jennings, KaVontae Turpin, Kalif Raymond, KhaDarel Hodge, Marquez Valdes-Scantling, Michael Wilson, Noah Brown, Olamide Zaccheaus, Ray-Ray McCloud, Rome Odunze, Romeo Doubs, Sterling Shepard, Tim Patrick, Trent Sherfield, Trey Palmer, Xavier Legette, Zach Pascal, Zay Jones
#
# Cluster Averages:
# Games_Played: 71.19
# predicted_points: 3.63
# Rec_avg: 1.80
# Yds_avg: 22.92
# TD_avg: 0.15
# FL_avg: 0.02
#
# Clustering analysis complete.
